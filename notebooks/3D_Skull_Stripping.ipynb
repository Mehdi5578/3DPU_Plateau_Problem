# %%
import os
import torch
import matplotlib.pyplot as plt
import nibabel as nb
import numpy as np
import time
from tqdm import tqdm
from _3dpu import *

# %%
import os
os.chdir(r"C:\Users\oudao\OneDrive\Documents\Montréal 4A\Les études\Chair AI-SCALE")
# Now your working directory is changed, and you can open the file with a relative path

# %%
# !pip3 install ipympl
# %matplotlib widget
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: ipympl in c:\users\oudao\onedrive\documents\montréal 4a\les études\chair_scale_ai\3dpu\integrating\lib\site-packages (0.9.3)
# Requirement already satisfied: ipython<9 in c:\users\oudao\onedrive\documents\montréal 4a\les études\chair_scale_ai\3dpu\integrating\lib\site-packages (from ipympl) (8.15.0)
# Requirement already satisfied: numpy in c:\users\oudao\onedrive\documents\montréal 4a\les études\chair_scale_ai\3dpu\integrating\lib\site-packages (from ipympl) (1.25.2)
# Requirement already satisfied: ipython-genutils in c:\users\oudao\onedrive\documents\montréal 4a\les études\chair_scale_ai\3dpu\integrating\lib\site-packages (from ipympl) (0.2.0)
# Requirement already satisfied: pillow in c:\users\oudao\onedrive\documents\montréal 4a\les études\chair_scale_ai\3dpu\integrating\lib\site-packages (from ipympl) (10.0.0)
# Requirement already satisfied: traitlets<6 in c:\users\oudao\onedrive\documents\montréal 4a\les études\chair_scale_ai\3dpu\integrating\lib\site-packages (from ipympl) (5.9.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in c:\users\oudao\onedrive\documents\montréal 4a\les études\chair_scale_ai\3dpu\integrating\lib\site-packages (from ipympl) (8.1.1)
# Requirement already satisfied: matplotlib<4,>=3.4.0 in c:\users\oudao\onedrive\documents\montréal 4a\les études\chair_scale_ai\3dpu\integrating\lib\site-packages (from ipympl) (3.7.2)
# Requirement already satisfied: backcall in c:\users\oudao\onedrive\documents\montréal 4a\les études\chair_scale_ai\3dpu\integrating\lib\site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: decorator in c:\users\oudao\onedrive\documents\montréal 4a\les études\chair_scale_ai\3dpu\integrating\lib\site-packages (from ipython<9->ipympl) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\oudao\onedrive\documents\montréal 4a\les études\chair_scale_ai\3dpu\integrating\lib\site-packages (from ipython<9->ipympl) (0.19.0)
# Requirement already satisfied: matplotlib-inline in c:\users\oudao\onedrive\documents\montréal 4a\les études\chair_scale_ai\3dpu\integrating\lib\site-packages (from ipython<9->ipympl) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\oudao\onedrive\documents\montréal 4a\les études\chair_scale_ai\3dpu\integrating\lib\site-packages (from ipython<9->ipympl) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\oudao\onedrive\documents\montréal 4a\les études\chair_scale_ai\3dpu\integrating\lib\site-packages (from ipython<9->ipympl) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\oudao\onedrive\documents\montréal 4a\les études\chair_scale_ai\3dpu\integrating\lib\site-packages (from ipython<9->ipympl) (2.16.1)
# Requirement already satisfied: stack-data in c:\users\oudao\onedrive\documents\montréal 4a\les études\chair_scale_ai\3dpu\integrating\lib\site-packages (from ipython<9->ipympl) (0.6.2)
# Requirement already satisfied: colorama in c:\users\oudao\onedrive\documents\montréal 4a\les études\chair_scale_ai\3dpu\integrating\lib\site-packages (from ipython<9->ipympl) (0.4.6)
# Requirement already satisfied: comm>=0.1.3 in c:\users\oudao\onedrive\documents\montréal 4a\les études\chair_scale_ai\3dpu\integrating\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (0.1.4)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in c:\users\oudao\onedrive\documents\montréal 4a\les études\chair_scale_ai\3dpu\integrating\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in c:\users\oudao\onedrive\documents\montréal 4a\les études\chair_scale_ai\3dpu\integrating\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\oudao\onedrive\documents\montréal 4a\les études\chair_scale_ai\3dpu\integrating\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\oudao\onedrive\documents\montréal 4a\les études\chair_scale_ai\3dpu\integrating\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\oudao\onedrive\documents\montréal 4a\les études\chair_scale_ai\3dpu\integrating\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\oudao\onedrive\documents\montréal 4a\les études\chair_scale_ai\3dpu\integrating\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\oudao\onedrive\documents\montréal 4a\les études\chair_scale_ai\3dpu\integrating\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\oudao\onedrive\documents\montréal 4a\les études\chair_scale_ai\3dpu\integrating\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\oudao\onedrive\documents\montréal 4a\les études\chair_scale_ai\3dpu\integrating\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (2.8.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\oudao\onedrive\documents\montréal 4a\les études\chair_scale_ai\3dpu\integrating\lib\site-packages (from jedi>=0.16->ipython<9->ipympl) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\oudao\onedrive\documents\montréal 4a\les études\chair_scale_ai\3dpu\integrating\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython<9->ipympl) (0.2.6)
# Requirement already satisfied: six>=1.5 in c:\users\oudao\onedrive\documents\montréal 4a\les études\chair_scale_ai\3dpu\integrating\lib\site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.4.0->ipympl) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\oudao\onedrive\documents\montréal 4a\les études\chair_scale_ai\3dpu\integrating\lib\site-packages (from stack-data->ipython<9->ipympl) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\oudao\onedrive\documents\montréal 4a\les études\chair_scale_ai\3dpu\integrating\lib\site-packages (from stack-data->ipython<9->ipympl) (2.4.0)
# Requirement already satisfied: pure-eval in c:\users\oudao\onedrive\documents\montréal 4a\les études\chair_scale_ai\3dpu\integrating\lib\site-packages (from stack-data->ipython<9->ipympl) (0.2.2)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
chemin = r"C:\Users\oudao\OneDrive\Documents\Montréal 4A\Les études\Chair AI-SCALE\ph.nii"

# chemin_mag = r"C:\Users\0\OneDrive\Documents\Montréal 4A\Les études\Chair AI-SCALE\mag_1.nii"
# chemin2 = r"C:\Users\0\Downloads\TGVQSM-plus\TGVQSM-master-011045626121baa8bfdd6633929974c732ae35e3\test_data\epi3d_test_phase.nii"
# chemin3 = r"C:\Users\0\Downloads\20170327_qsm2016_recon_challenge\20170327_qsm2016_recon_challenge\data\phs_wrap.nii"
phase_image = nb.load(chemin)
# mag_imgae = nb.load(chemin_mag)
# phase_image2 = nb.load(chemin2)
# phase_image3 = nb.load(chemin3)
# x_min,x_max = 50,130
# y_min,y_max = 50,130
# z_min,z_max = 20,60
t = 1
data = phase_image.get_fdata()[:,:,:,t]

# %%
len(data)
# Out:
# 208

# %% [markdown]
# # **Brain Extraction Using U-Net**   (3D and Auto)

# %% [markdown]
# # Otsu Separation

# %%
i,j,k = 0,0,0
Z = np.array(mag_data)
Z = Z.flatten()
values,n = np.unique(Z,return_counts=True)
proba = n/len(Z)

# %%
def threshold_image(im,th):
    thresholded_im = np.zeros(im.shape)
    thresholded_im[im >= th] = 1
    return thresholded_im

# %%
def compute_otsu_criteria(im, th):
    thresholded_im = threshold_image(im,th)
    nb_pixels = im.size
    nb_pixels1 = np.count_nonzero(thresholded_im)
    weight1 = nb_pixels1 / nb_pixels
    weight0 = 1 - weight1
    if weight1 == 0 or weight0 == 0:
        return np.inf
    val_pixels1 = im[thresholded_im == 1]
    val_pixels0 = im[thresholded_im == 0]
    var0 = np.var(val_pixels0) if len(val_pixels0) > 0 else 0
    var1 = np.var(val_pixels1) if len(val_pixels1) > 0 else 0
    return weight0 * var0 + weight1 * var1

# %%
def find_best_threshold(im):
    threshold_range = range(int(np.max((im)))+1)
    criterias = [compute_otsu_criteria(im, th) for th in (threshold_range)]
    best_threshold = threshold_range[np.argmin(criterias)]
    return best_threshold

# %% [markdown]
# # UNet Model

# %%
import torch.nn as nn

class Conv3DBlock(nn.Module):
    
    def __init__(self, in_channels, out_channels, bottleneck = False) -> None:
        super(Conv3DBlock, self).__init__()
        self.conv1 = nn.Conv3d(in_channels= in_channels, out_channels=out_channels//2, kernel_size=(3,3,3), padding=1)
        self.bn1 = nn.BatchNorm3d(num_features=out_channels//2)
        self.conv2 = nn.Conv3d(in_channels= out_channels//2, out_channels=out_channels, kernel_size=(3,3,3), padding=1)
        self.bn2 = nn.BatchNorm3d(num_features=out_channels)
        self.relu = nn.ReLU()
        self.bottleneck = bottleneck
        if not bottleneck:
            self.pooling = nn.MaxPool3d(kernel_size=(2,2,2), stride=2)

    def forward(self, input):
        res = self.relu(self.bn1(self.conv1(input)))
        res = self.relu(self.bn2(self.conv2(res)))
        out = None
        if not self.bottleneck:
            out = self.pooling(res)
        else:
            out = res
        return out, res

# %%
class UpConv3DBlock(nn.Module):

    def __init__(self, in_channels, res_channels=0, last_layer=False, num_classes=None) -> None:
        super(UpConv3DBlock, self).__init__()
        assert (last_layer==False and num_classes==None) or (last_layer==True and num_classes!=None), 'Invalid arguments'
        self.upconv1 = nn.ConvTranspose3d(in_channels=in_channels, out_channels=in_channels, kernel_size=(2, 2, 2), stride=2)
        self.relu = nn.ReLU()
        self.bn = nn.BatchNorm3d(num_features=in_channels//2)
        self.conv1 = nn.Conv3d(in_channels=in_channels+res_channels, out_channels=in_channels//2, kernel_size=(3,3,3), padding=(1,1,1))
        self.conv2 = nn.Conv3d(in_channels=in_channels//2, out_channels=in_channels//2, kernel_size=(3,3,3), padding=(1,1,1))
        self.last_layer = last_layer
        if last_layer:
            self.conv3 = nn.Conv3d(in_channels=in_channels//2, out_channels=num_classes, kernel_size=(1,1,1))
            
        
    def forward(self, input, residual=None):
        out = self.upconv1(input)
        if residual!=None: out = torch.cat((out, residual), 1)
        out = self.relu(self.bn(self.conv1(out)))
        out = self.relu(self.bn(self.conv2(out)))
        if self.last_layer: out = self.conv3(out)
        return out

# %%
class UNet3D(nn.Module):
    
    def __init__(self, in_channels, num_classes, level_channels=[32, 32], bottleneck_channel=64) -> None:
        super(UNet3D, self).__init__()
        level_1_chnls, level_2_chnls = level_channels[0], level_channels[1]
        self.a_block1 = Conv3DBlock(in_channels=in_channels, out_channels=level_1_chnls)
        self.a_block2 = Conv3DBlock(in_channels=level_1_chnls, out_channels=level_2_chnls)
        
        self.bottleNeck = Conv3DBlock(in_channels=level_2_chnls, out_channels=bottleneck_channel, bottleneck= True)
        
        self.s_block2 = UpConv3DBlock(in_channels=bottleneck_channel, res_channels=level_2_chnls)
        self.s_block1 = UpConv3DBlock(in_channels=level_2_chnls, res_channels=level_1_chnls, num_classes=num_classes, last_layer=True)

    
    def forward(self, input):
        out, residual_level1 = self.a_block1(input)
        out, residual_level2 = self.a_block2(out)
        out, _ = self.bottleNeck(out)
        out = self.s_block2(out, residual_level2)
        out = self.s_block1(out, residual_level1)
        return out

# %%
model = UNet3D(in_channels = 1, num_classes = 1)
mask = (mag_data > 46)
mask = torch.Tensor(mask).unsqueeze(0).unsqueeze(0)
cv3 = nn.Conv3d(in_channels= 1, out_channels=3//2, kernel_size=(3,3,3), padding=1)
resp = model(mask)

# %% [markdown]
# # Using Erosion dilation

# %%
# # plt.figure()
# # plt.imshow(resp[0,0,:,:,15].detach().numpy())

# Z = 100*np.array(resp.detach().numpy())
# Z = Z.flatten()


# th = find_best_threshold(Z)
# th
mask = mag_data
img= mask
img = np.array(img*255,dtype = np.uint8)
plt.figure()


# dilation = cv2.dilate(img,kernel,iterations = 1)


kernel = np.ones((5,5),np.uint8)
erosion = cv2.erode(img,np.ones((10,10),np.uint8),iterations = 1)
dilation = cv2.dilate(erosion,np.ones((10,10),np.uint8),iterations = 1)

Z = img.flatten()
plt.hist(Z,bins = 100)
# Out:
# (array([7.062430e+05, 3.900000e+01, 2.600000e+01, 5.800000e+01,
#         5.200000e+01, 7.500000e+01, 5.500000e+01, 9.300000e+01,
#         6.600000e+01, 1.050000e+02, 1.170000e+02, 8.300000e+01,
#         1.560000e+02, 1.200000e+02, 2.100000e+02, 1.390000e+02,
#         2.480000e+02, 2.070000e+02, 3.170000e+02, 2.790000e+02,
#         4.370000e+02, 5.540000e+02, 4.270000e+02, 6.630000e+02,
#         5.120000e+02, 8.750000e+02, 6.160000e+02, 1.046000e+03,
#         8.160000e+02, 1.313000e+03, 1.604000e+03, 1.147000e+03,
#         2.097000e+03, 1.481000e+03, 2.613000e+03, 1.951000e+03,
#         3.196000e+03, 2.461000e+03, 4.013000e+03, 3.110000e+03,
#         5.464000e+03, 6.369000e+03, 4.826000e+03, 8.113000e+03,
#         6.041000e+03, 1.021900e+04, 7.620000e+03, 1.262000e+04,
#         9.163000e+03, 1.559600e+04, 1.709100e+04, 1.247000e+04,
#         2.035500e+04, 1.474400e+04, 2.401400e+04, 1.743300e+04,
#         2.837500e+04, 2.034900e+04, 3.193300e+04, 2.238300e+04,
#         3.551900e+04, 3.843300e+04, 2.731700e+04, 4.324800e+04,
#         3.093500e+04, 4.961900e+04, 3.516000e+04, 5.638800e+04,
#         3.958100e+04, 6.326000e+04, 6.740200e+04, 4.917600e+04,
#         8.029300e+04, 5.518100e+04, 8.198400e+04, 5.192400e+04,
#         6.714600e+04, 3.757600e+04, 4.457500e+04, 2.483000e+04,
#         3.314300e+04, 2.851300e+04, 1.719600e+04, 2.435000e+04,
#         1.546700e+04, 2.229900e+04, 1.469900e+04, 2.232800e+04,
#         1.509400e+04, 2.397100e+04, 2.590200e+04, 1.878300e+04,
#         3.244200e+04, 2.509100e+04, 4.583300e+04, 3.851900e+04,
#         7.703500e+04, 7.235200e+04, 1.929410e+05, 1.393041e+06]),
#  array([  0.  ,   2.55,   5.1 ,   7.65,  10.2 ,  12.75,  15.3 ,  17.85,
#          20.4 ,  22.95,  25.5 ,  28.05,  30.6 ,  33.15,  35.7 ,  38.25,
#          40.8 ,  43.35,  45.9 ,  48.45,  51.  ,  53.55,  56.1 ,  58.65,
#          61.2 ,  63.75,  66.3 ,  68.85,  71.4 ,  73.95,  76.5 ,  79.05,
#          81.6 ,  84.15,  86.7 ,  89.25,  91.8 ,  94.35,  96.9 ,  99.45,
#         102.  , 104.55, 107.1 , 109.65, 112.2 , 114.75, 117.3 , 119.85,
#         122.4 , 124.95, 127.5 , 130.05, 132.6 , 135.15, 137.7 , 140.25,
#         142.8 , 145.35, 147.9 , 150.45, 153.  , 155.55, 158.1 , 160.65,
#         163.2 , 165.75, 168.3 , 170.85, 173.4 , 175.95, 178.5 , 181.05,
#         183.6 , 186.15, 188.7 , 191.25, 193.8 , 196.35, 198.9 , 201.45,
#         204.  , 206.55, 209.1 , 211.65, 214.2 , 216.75, 219.3 , 221.85,
#         224.4 , 226.95, 229.5 , 232.05, 234.6 , 237.15, 239.7 , 242.25,
#         244.8 , 247.35, 249.9 , 252.45, 255.  ]),
#  <BarContainer object of 100 artists>)

# %%
mask = np.array(mag_data > 46 ,np.uint8)[:,:,45]*255
image = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)

# %%
mag_data.shape[2]
# Out:
# 96

# %%
import cv2
import numpy as np

Mask = np.zeros((mag_data.shape))
for i in tqdm(range(mag_data.shape[2])):
    # Read image
    
    deb = time.time()

    # Threshold.
    # Set values equal to or above 220 to 0.
    # Set values below 220 to 255.
    M = mag_data[:,:,i]
    th = find_best_threshold(M)
    mask = np.array(mag_data > th ,np.uint8)[:,:,i]*255
    image = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)
    im_th = image

    # Copy the thresholded image.
    im_floodfill = im_th.copy()
    fin1 = time.time()


    # Mask used to flood filling.
    # Notice the size needs to be 2 pixels than the image.
    h, w = im_th.shape[:2]
    mask = np.zeros((h+2, w+2), np.uint8)

    fin2 = time.time()

    # Floodfill from point (0, 0)
    cv2.floodFill(im_floodfill, mask, (0,0), 255);

    # Invert floodfilled image
    im_floodfill_inv = cv2.bitwise_not(im_floodfill)
    fin3 = time.time()


    # Combine the two images to get the foreground.
    im_out = im_th | im_floodfill_inv

    Mask[:,:,i] = im_out[:,:,0]

    

# Display images.
# cv2.imshow("Thresholded Image", im_th)
# cv2.imshow("Floodfilled Image", im_floodfill)
# cv2.imshow("Inverted Floodfilled Image", im_floodfill_inv)
# cv2.imshow("Foreground", im_out)
# cv2.waitKey(0)
# Out:
# 100%|██████████| 96/96 [00:17<00:00,  5.36it/s]

# %%
cv2.imshow("Thresholded Image", im_th)
cv2.imshow("Floodfilled Image", im_floodfill)
cv2.imshow("Inverted Floodfilled Image", im_floodfill_inv)
cv2.imshow("Foreground", im_out)
cv2.waitKey(0)
# Out:
# 0

# %%
plt.figure()
# plt.imshow(Mask[:,:,19])

M = mag_data[:,:,5]
th = find_best_threshold(M)

im_th = mask = np.array(mag_data > th ,np.uint8)[:,:,5]*255

# Copy the thresholded image.
im_floodfill = im_th.copy()
fin1 = time.time()


# Mask used to flood filling.
# Notice the size needs to be 2 pixels than the image.
h, w = im_th.shape[:2]
mask = np.zeros((h+2, w+2), np.uint8)

fin2 = time.time()

# Floodfill from point (0, 0)
cv2.floodFill(im_floodfill, mask, (0,0), 255);

# Invert floodfilled image
im_floodfill_inv = cv2.bitwise_not(im_floodfill)
fin3 = time.time()


# Combine the two images to get the foreground.
im_out = im_th | im_floodfill_inv

# Mask[:,:,i] = im_out[:,:,0]

plt.imshow(mag_data[:,:,5])

# %% [markdown]
# # Begin Detangling

# %%
psi = data
shape = psi.shape
# Store the list of all residuals.
res = []
for a in tqdm(range(dim)):
    res.append(residuals(psi, a))
marker1 = {}
unprocess_all(res, marker1)

len(marker1.items())
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# 100%|██████████| 3/3 [00:00<00:00,  4.07it/s]
# 1939313

# %%
import time
deb = time.time()
marker2 = {}
loops = []
l = residual_loops(loops,marker2,data)
fin = time.time()
print(fin-deb)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\oudao\OneDrive\Documents\Montréal 4A\Les études\Chair_SCALE_AI\3dPU\notebooks\3D_Skull_Stripping.ipynb Cell 26 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/oudao/OneDrive/Documents/Montr%C3%A9al%204A/Les%20%C3%A9tudes/Chair_SCALE_AI/3dPU/notebooks/3D_Skull_Stripping.ipynb#X34sZmlsZQ%3D%3D?line=2'>3</a> marker2 = {}
#       <a href='vscode-notebook-cell:/c%3A/Users/oudao/OneDrive/Documents/Montr%C3%A9al%204A/Les%20%C3%A9tudes/Chair_SCALE_AI/3dPU/notebooks/3D_Skull_Stripping.ipynb#X34sZmlsZQ%3D%3D?line=3'>4</a> loops = []
# ----> <a href='vscode-notebook-cell:/c%3A/Users/oudao/OneDrive/Documents/Montr%C3%A9al%204A/Les%20%C3%A9tudes/Chair_SCALE_AI/3dPU/notebooks/3D_Skull_Stripping.ipynb#X34sZmlsZQ%3D%3D?line=4'>5</a> l = residual_loops(loops,marker2,data)
#       <a href='vscode-notebook-cell:/c%3A/Users/oudao/OneDrive/Documents/Montr%C3%A9al%204A/Les%20%C3%A9tudes/Chair_SCALE_AI/3dPU/notebooks/3D_Skull_Stripping.ipynb#X34sZmlsZQ%3D%3D?line=5'>6</a> fin = time.time()
#       <a href='vscode-notebook-cell:/c%3A/Users/oudao/OneDrive/Documents/Montr%C3%A9al%204A/Les%20%C3%A9tudes/Chair_SCALE_AI/3dPU/notebooks/3D_Skull_Stripping.ipynb#X34sZmlsZQ%3D%3D?line=6'>7</a> print(fin-deb)
#
# File c:\Users\oudao\OneDrive\Documents\Montréal 4A\Les études\Chair_SCALE_AI\3dPU\notebooks\_3dpu.py:258, in residual_loops(loops, marker, psi)
#     256     break
#     257 # print("on cherche la loop avec serach loop")
# --> 258 flagged_loop = search_loop(SpinnedResidual(1, r), shape, marker, False)
#     259 loop = flagged_loop.loop
#     260 # print("on a trouvé une loop")
#     261 # If the loop is closed.
#
# File c:\Users\oudao\OneDrive\Documents\Montréal 4A\Les études\Chair_SCALE_AI\3dPU\notebooks\_3dpu.py:205, in search_loop(start, shape, marker, rev)
#     202     return FlaggedLoop(True, loop)
#     203 else:
#     204     # Get the next residual.
# --> 205     neighbor = next_residual(curr, marker)
#     206     if neighbor:
#     207         curr = neighbor
#
# File c:\Users\oudao\OneDrive\Documents\Montréal 4A\Les études\Chair_SCALE_AI\3dPU\notebooks\_3dpu.py:145, in next_residual(curr, marker, reverse, shuffle)
#     143 def next_residual(curr: SpinnedResidual, marker: ResidualMarker, reverse: bool = False, shuffle: bool = True) -> Optional[SpinnedResidual]:
#     144     # List of potential neighbors.
# --> 145     neighbors = potential_neighbors(curr, reverse)
#     147     # Shuffle the list of neighbors if asked to.
#     148     if shuffle:
#
# File c:\Users\oudao\OneDrive\Documents\Montréal 4A\Les études\Chair_SCALE_AI\3dPU\notebooks\_3dpu.py:136, in potential_neighbors(self, reverse)
#     134 def potential_neighbors(self : SpinnedResidual, reverse:bool = False ) -> list[SpinnedResidual]:
#     135     if not(reverse) :
# --> 136         return potential_neighbors_no_reverse(self)
#     138     else:
#     139         curr = deepcopy(self)
#
# File c:\Users\oudao\OneDrive\Documents\Montréal 4A\Les études\Chair_SCALE_AI\3dPU\notebooks\_3dpu.py:114, in potential_neighbors_no_reverse(self)
#     111 neighbors = []
#     112 # Add the neighbor with the same axis as
#     113 # the current residual.
# --> 114 npos = deepcopy(self.res.pos)
#     115 npos[self.res.ax] += self.spin
#     116 neighbors.append(SpinnedResidual(self.spin, Residual(self.res.ax, self.res.ori, npos)))
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1776.0_x64__qbz5n2kfra8p0\Lib\copy.py:153, in deepcopy(x, memo, _nil)
#     151 copier = getattr(x, "__deepcopy__", None)
#     152 if copier is not None:
# --> 153     y = copier(memo)
#     154 else:
#     155     reductor = dispatch_table.get(cls)
#
# KeyboardInterrupt:

# %%
closed = [len(l.loop) for l in loops]
(loops[0].loop[0].res.pos)
def extract_residuals (loop : Loop ):
    lasso_positions = []
    for r in loop:
        pos = [r.res.ax] + list(r.res.pos)
        if pos[0] == 2:
            new_pos = [pos[1]+0.5,pos[2] + 0.5,pos[3]]
        elif pos[0] == 1:
            new_pos = [pos[1]+0.5,pos[2],pos[3]+0.5]
        elif pos[0] == 0:
            new_pos = [pos[1],pos[2] + 0.5,pos[3]+0.5]
        lasso_positions.append(new_pos)
    return np.array(lasso_positions) 


positions = extract_residuals(loops[0].loop)
np.min(positions[:,0])
# Out:
# 0.5

# %%
cpt = 0
for i in tqdm(marker2.values()):
    cpt = cpt + (i == 1)
# Out:
# 100%|██████████| 1939313/1939313 [00:00<00:00, 3070706.55it/s]

# %%
cpt
# Out:
# 85102

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_aspect('equal')
X = []
Y = []
Z = []
for loop in loops:
    if True:
        lasso_positions = []
        for r in loop.loop:
            pos = [r.res.ax] + list(r.res.pos)
            if pos[0] == 2:
                new_pos = [pos[1]+0.5,pos[2] + 0.5,pos[3]]
            elif pos[0] == 1:
                new_pos = [pos[1]+0.5,pos[2],pos[3]+0.5]
            elif pos[0] == 0:
                new_pos = [pos[1],pos[2] + 0.5,pos[3]+0.5]
                
            lasso_positions.append(new_pos)
        xs = [pos[0] for pos in lasso_positions]
        ys = [pos[1] for pos in lasso_positions]
        zs = [pos[2] for pos in lasso_positions]
        xs = xs 
        ys = ys 
        zs = zs 
        ax.plot(xs,ys,zs)
        Z = Z + zs
        X = X + xs
        Y = Y + ys

X = np.array(X)
Y = np.array(Y)
Z = np.array(Z)
max_range = np.array([X.max()-X.min(), Y.max()-Y.min(), Z.max()-Z.min()]).max() / 2.0 

mid_x = (X.max()+X.min()) * 0.5
mid_y = (Y.max()+Y.min()) * 0.5
mid_z = (Z.max()+Z.min()) * 0.5
ax.set_xlim(mid_x - max_range, mid_x + max_range)
ax.set_ylim(mid_y - max_range, mid_y + max_range)
ax.set_zlim(mid_z - max_range, mid_z + max_range)
# Out:
# (-7.25, 102.25)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig = plt.figure()
plt.hist(sorted(closed)[7400:])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
